# %% [markdown]
# # Stock Test
# ## Stock data analysis with neural networks

# %%
import pandas as pd
from bokeh.plotting import show, figure, output_notebook
# get data first
df = pd.read_csv('../rawData/^GDAXI.csv')

output_file('my_first_graph.html')
p = figure()
p.line(df['Date'], df['Close'], color='Blue', legend='DAX')
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1489">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="31eed3a0-48c4-400d-9fef-c52c5ac5c0a7" data-root-id="1443"></div>

# %%
df
# Out:
#             Date          Open  ...     Adj Close      Volume
# 0     1987-12-30   1005.190002  ...   1005.190002         0.0
# 1     1987-12-31           NaN  ...           NaN         NaN
# 2     1988-01-01           NaN  ...           NaN         NaN
# 3     1988-01-04    956.489990  ...    956.489990         0.0
# 4     1988-01-05    996.099976  ...    996.099976         0.0
# ...          ...           ...  ...           ...         ...
# 8535  2021-02-17  14028.099609  ...  13909.269531  81266800.0
# 8536  2021-02-18  13926.839844  ...  13886.929688  67920700.0
# 8537  2021-02-19  13941.400391  ...  13993.230469  72974000.0
# 8538  2021-02-22  13858.559570  ...  13950.040039  66035300.0
# 8539  2021-02-23  13984.980469  ...  13864.809570  88194700.0
#
# [8540 rows x 7 columns]
